# %% [markdown]
# <a href="https://colab.research.google.com/github/darlinesther2006-bot/project/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# E-Commerece Sales Performance Analysis

# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data ={
    "Order_ID": [101, 102, 103, 104, 105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,101],
    "Product": ["Laptop", "Smartphone", "Tablet", "Headphones", "Monitor", "Keyboard", "Mouse", "Charger", "Webcam", "Printer","Speaker","Smartwatch","USB Drive","Power Bank","Scanner","Router","External Hard Drive","Gaming Laptop","Wireless Mouse","Laptpo"],
    "Quantity" : [ 8, 8, 1, 4, 5, 5, 9, 8, np.nan, 6, np.nan, 4, 8, 9, 6, 4, 2, 1, 8, 2,],
    "Amount" : [3000, 24000, 4000, 3000, np.nan, 10000, np.nan, 24000, 49000, 15000,34000,45000,16000,10000,3000,40000,20000,50000,np.nan,4000,],
    "Month" : ["April","March","August","July","May","March","September","April","April","July","April","September","Auguest","January","March","May","July","June","April","April",""],
    "Region": ["North","West","West","West",np.nan,"South","West","East",np.nan,"East","North","East","West","South","West","South","North","East","West","East"]

}
df = pd.DataFrame(data)
print (df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5554/2102474434.py in <cell line: 0>()
#      16
#      17 }
# ---> 18 df = pd.DataFrame(data)
#      19 print (df)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     501             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     502
# ...

# %%
df.to_csv("Sales_data.csv", index=False)
print("ORIGINAL DATASET")
print(df)
print("\nShape:", df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5554/51529899.py in <cell line: 0>()
# ----> 1 df.to_csv("Sales_data.csv", index=False)
#       2 print("ORIGINAL DATASET")
#       3 print(df)
#       4 print("\nShape:", df.shape)
#
# NameError: name 'df' is not defined

# %%
print(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5554/3729710734.py in <cell line: 0>()
# ----> 1 print(df.isnull().sum())
#
# NameError: name 'df' is not defined

# %%
df= df.drop_duplicates
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5554/1110410404.py in <cell line: 0>()
# ----> 1 df= df.drop_duplicates
#       2 print(df)
#
# NameError: name 'df' is not defined
